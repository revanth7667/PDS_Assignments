# %% [markdown]
# # Plotting Exercises, Part 1

# %% [markdown]
# ### Exercise 1
#
# Create a pandas dataframe from the "Datasaurus.txt" file using the code:

# %% [markdown]
# Note that the file being downloaded is *not* actually a CSV file. It is tab-delimited, meaning that within each row, columns are separated by tabs rather than commas. We communicate this to pandas with the `delimiter="\t"` option (`"\t"` is how we write a tab, as we will discuss in future lessons).

# %%
# Importing Required Packages
import pandas as pd
import seaborn.objects as so
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# setting default options
pd.set_option("mode.copy_on_write", True)
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# Loading the data
df = pd.read_csv(
    "https://raw.githubusercontent.com/nickeubank/practicaldatascience"
    "/master/Example_Data/Datasaurus.txt",
    delimiter="\t",
)

# %%
df.sample(5)
# Out:
#     example1_x  example1_y  example2_x  example2_y  example3_x  example3_y  \
# 50   64.405075   78.584176   59.503077   30.669674   47.352416   17.134745
# 60   71.965083   17.710236   72.470953   51.122135   77.931005   68.690062
# 72   30.052290   96.617542   46.480768   83.518212   53.081242   79.297251
# 37   21.778040    6.616625   41.389523   37.296056   39.485575   20.033050
# 73   28.003324   46.672192   53.174656   84.260568   56.475383   79.167840
#
#     example4_x  example4_y  example5_x  example5_y  ...  example9_x  \
# 50     47.1795     28.7180   50.564846   17.077777  ...   55.589877
# 60     70.5128     53.7180   77.254388   51.461825  ...   80.352934
# 72     51.2821     78.7180   50.488014   83.099519  ...   55.044123
# 37     35.1282     30.2564   25.855128   17.081909  ...   36.619722
# 73     50.0000     78.7180   49.964905   83.708318  ...   50.444185
#
#     example9_y  example10_x  example10_y  example11_x  example11_y  \
# 50   26.299245    41.968617    26.497073    50.173177    29.177864
# 60   47.800299    69.647021    44.044445    69.495756    58.785073
# 72   83.541411    54.575729    77.536288    50.087058    73.951874
# 37   36.811414    41.640454    27.093095    30.503474    38.348556
# 73   78.195888    54.413094    78.229087    50.231072    80.647387
#
#     example12_x  example12_y  example13_x  example13_y
# 50    37.519636    29.267606    42.346262    24.558327
# 60    68.675516    50.465235    61.908040    53.190352
# 72    64.295218    84.125857    43.856898    77.609844
# 37    31.090065    32.383755    40.915972    23.541592
# 73    38.798012    74.610630    42.367823    73.638272
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   example1_x   142 non-null    float64
#  1   example1_y   142 non-null    float64
#  2   example2_x   142 non-null    float64
#  3   example2_y   142 non-null    float64
#  4   example3_x   142 non-null    float64
#  5   example3_y   142 non-null    float64
#  6   example4_x   142 non-null    float64
#  7   example4_y   142 non-null    float64
#  8   example5_x   142 non-null    float64
#  9   example5_y   142 non-null    float64
#  10  example6_x   142 non-null    float64
#  11  example6_y   142 non-null    float64
#  12  example7_x   142 non-null    float64
#  13  example7_y   142 non-null    float64
#  14  example8_x   142 non-null    float64
#  15  example8_y   142 non-null    float64
#  16  example9_x   142 non-null    float64
#  17  example9_y   142 non-null    float64
#  18  example10_x  142 non-null    float64
#  19  example10_y  142 non-null    float64
#  20  example11_x  142 non-null    float64
#  21  example11_y  142 non-null    float64
#  22  example12_x  142 non-null    float64
#  23  example12_y  142 non-null    float64
#  24  example13_x  142 non-null    float64
#  25  example13_y  142 non-null    float64
# dtypes: float64(26)
# memory usage: 29.0 KB

# %% [markdown]
# ### Exercise 2
#
# This dataset actually contains 13 separate example datasets, each with two variables named `example[number]_x` and `example[number]_y`.
#
# In order to get a better sense of what these datasets look like, write a loop that iterates over each example dataset (numbered 1 to 13) and print out the mean and standard deviation for `example[number]_x` and `example[number]_y` for each dataset.
#
# For example, the first iteration of this loop might return something like:
#
# ```
# Example Dataset 1:
# Mean x: 23.12321978429576,
# Mean y: 98.23980921730972,
# Std Dev x: 21.2389710287,
# Std Dev y: 32.2389081209832,
# Correlation: 0.73892819281
# ```
#
# (Though you shouldn't get those specific values)

# %%
# Print Summary stats for the dataset

# Loop through the Dataset
for i in range(1, 14):
    print(f"Example Dataset {i}:")
    x_col = f"example{i}_x"
    y_col = f"example{i}_y"

    print(f"Mean x: {df[x_col].mean()}")
    print(f"Mean y: {df[y_col].mean()}")
    print(f"Standard Deviation x: {df[x_col].std()}")
    print(f"Standard Deviation y: {df[y_col].std()}")
    print(f"Correlation: {df[x_col].corr(df[y_col])}")
    print("---------------------------------------------")
# Out:
# Example Dataset 1:
# Mean x: 54.266099784295776
# Mean y: 47.834720624943664
# Standard Deviation x: 16.769824954043756
# Standard Deviation y: 26.9397434192671
# Correlation: -0.0641283521673984
# ---------------------------------------------
# Example Dataset 2:
# Mean x: 54.268730022394365
# Mean y: 47.83082315530282
# Standard Deviation x: 16.769239493454403
# Standard Deviation y: 26.935726689918784
# Correlation: -0.06858639424107654
# ---------------------------------------------
# Example Dataset 3:
# Mean x: 54.26731970598592
# Mean y: 47.83771726725352
# Standard Deviation x: 16.76001265980608
# Standard Deviation y: 26.930036087838204
# Correlation: -0.06834335648025565
# ---------------------------------------------
# Example Dataset 4:
# Mean x: 54.26327323943662
# Mean y: 47.832252816901416
# Standard Deviation x: 16.76514203911679
# Standard Deviation y: 26.935403486939116
# Correlation: -0.06447185270095167
# ---------------------------------------------
# Example Dataset 5:
# Mean x: 54.26030345169014
# Mean y: 47.839829209014084
# Standard Deviation x: 16.767735488473807
# Standard Deviation y: 26.93019151853346
# Correlation: -0.06034144199921764
# ---------------------------------------------
# Example Dataset 6:
# Mean x: 54.26144178316902
# Mean y: 47.83025191366197
# Standard Deviation x: 16.765897903899337
# Standard Deviation y: 26.93987622043797
# Correlation: -0.06171483797263011
# ---------------------------------------------
# Example Dataset 7:
# Mean x: 54.26880527950703
# Mean y: 47.83545020401409
# Standard Deviation x: 16.766704015934764
# Standard Deviation y: 26.939997961411027
# Correlation: -0.06850422049412316
# ---------------------------------------------
# Example Dataset 8:
# Mean x: 54.26784882366197
# Mean y: 47.83589633112676
# Standard Deviation x: 16.76675894771805
# Standard Deviation y: 26.936104931679978
# Correlation: -0.068979735359512
# ---------------------------------------------
# Example Dataset 9:
# Mean x: 54.26588178542254
# Mean y: 47.831495652323945
# Standard Deviation x: 16.768852670828494
# Standard Deviation y: 26.93860807087184
# Correlation: -0.06860920641825635
# ---------------------------------------------
# Example Dataset 10:
# Mean x: 54.26734110478873
# Mean y: 47.83954522535211
# Standard Deviation x: 16.76895921619445
# Standard Deviation y: 26.93027468808843
# Correlation: -0.0629611002206542
# ---------------------------------------------
# Example Dataset 11:
# Mean x: 54.26992723091549
# Mean y: 47.836987988408445
# Standard Deviation x: 16.769958611325382
# Standard Deviation y: 26.937683806980512
# Correlation: -0.06944556959350369
# ---------------------------------------------
# Example Dataset 12:
# Mean x: 54.266916301197185
# Mean y: 47.83160198797184
# Standard Deviation x: 16.769999617573024
# Standard Deviation y: 26.937901927731797
# Correlation: -0.06657523020460904
# ---------------------------------------------
# Example Dataset 13:
# Mean x: 54.26015033415493
# Mean y: 47.839717279450696
# Standard Deviation x: 16.76995769550748
# Standard Deviation y: 26.93000168716234
# Correlation: -0.06558333729297582
# ---------------------------------------------

# %% [markdown]
# ### Exercise 3
#
# Based only on these results, discuss what might you conclude about these example datasets with your partner. Write down your thoughts.

# %% [markdown]
# ## Observations
# The Mean, Standard deviations and Correlation for x and y are very similar across the different example datasets. There is a very minor difference usually after the second decimal point. This suggets that the source for these samples migth be very similar, which can be confimred by checking other parameters or visually.

# %% [markdown]
# ### Execise 4
#
# Write a loop that iterates over these example datasets, and using Altair library, plot a simple scatter plot of each dataset with the `x` variable on the x-axis and the `y` variable on the y-axis.
#
# Hint: When writing this type of code, it is often best to start by writing code to do what you want for the first iteration of the loop. Once you have code that works for the first example dataset, then write the full loop around it.
#
# Hint 2: To force Jupyter to display your charts when they're generated within a loop, use the method `.show()` (e.g. `my_chart.show()`).
#
# Hint 3: You will need to change the range of the axes to make the plots look good!

# %%
# Loop through the Dataset and plot
for i in range(1, 14):
    x_col = f"example{i}_x"
    y_col = f"example{i}_y"

    plt.figure(figsize=(3, 3))
    sns.scatterplot(
        data=df,
        x=x_col,
        y=y_col,
    )
    plt.title(f"Example Data: {i}")
    plt.xlim(0, 100)
    plt.ylim(0, 100)
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

# %% [markdown]
# ### Exercise 5
#
# Review you plots. How does your impression of how these datasets differ from what you wrote down in Exercise 3?

# %% [markdown]
# ## Observations
# I initally thought that the source data would be similar after looking at the mean, std. etc. However, after looking at the plots, the source datas are completely different as compared to each other

# %% [markdown]
# ## Economic Development and... Your Choice!
#
# ### Exercise 6
#
# Load the World Development Indicator data used in the [plotting reading](https://nickeubank.github.io/practicaldatascience_book/notebooks/class_5/week_2/20_plotting_with_seaborn.html). Rather than picking a single year, pick a single country and look at how GDP per capita and one of the other variables in that dataset have evolved together over time.
#
# Make any adjustments to the functional forms of your variables and/or axes needed to make the figure legible.

# %%
# Load World Development Indicator data
df_wdi = pd.read_csv(
    "https://raw.githubusercontent.com/nickeubank/practicaldatascience/master/Example_Data/wdi_plotting.csv"
)

# %%
df_wdi.sample(5)
# Out:
#       Year          Country Name Country Code  \
# 6839  2002               Liberia          LBR
# 6928  2002                Tuvalu          TUV
# 4426  1991  Hong Kong SAR, China          HKG
# 3252  1985           Yemen, Rep.          YEM
# 2705  1983                 Kenya          KEN
#
#       GDP per capita (constant 2010 US$)  Population, total  \
# 6839                          617.811674          3024727.0
# 6928                         3315.783651             9593.0
# 4426                        19132.370660          5752000.0
# 3252                                 NaN          9572170.0
# 2705                          845.902242         18431760.0
#
#       CO2 emissions (metric tons per capita)  \
# 6839                                0.148774
# 6928                                1.042427
# 4426                                     NaN
# 3252                                0.329840
# 2705                                0.252866
#
#       Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)  \
# 6839                                                NaN
# 6928                                                NaN
# 4426                                                NaN
# 3252                                                NaN
# 2705                                                NaN
#
#       PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)  \
# 6839                                                NaN
# 6928                                                NaN
# 4426                                                NaN
# 3252                                                NaN
# 2705                                                NaN
#
#       Life expectancy at birth, total (years)  \
# 6839                                52.826000
# 6928                                      NaN
# 4426                                77.882927
# 3252                                54.120000
# 2705                                58.940000
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 6839                                            162.3
# 6928                                             38.9
# 4426                                              NaN
# 3252                                            153.5
# 2705                                            101.1
#
#       Literacy rate, youth female (% of females ages 15-24)
# 6839                                                NaN
# 6928                                                NaN
# 4426                                                NaN
# 3252                                                NaN
# 2705                                                NaN

# %%
df_wdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10850 entries, 0 to 10849
# Data columns (total 11 columns):
#  #   Column                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                       --------------  -----
#  0   Year                                                                                                         10850 non-null  int64
#  1   Country Name                                                                                                 10850 non-null  object
#  2   Country Code                                                                                                 10850 non-null  object
#  3   GDP per capita (constant 2010 US$)                                                                           8468 non-null   float64
#  4   Population, total                                                                                            10819 non-null  float64
#  5   CO2 emissions (metric tons per capita)                                                                       8745 non-null   float64
#  6   Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)  183 non-null    float64
#  7   PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                 2328 non-null   float64
#  8   Life expectancy at birth, total (years)                                                                      9642 non-null   float64
#  9   Mortality rate, under-5 (per 1,000 live births)                                                              9072 non-null   float64
#  10  Literacy rate, youth female (% of females ages 15-24)                                                        918 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 932.6+ KB

# %%
# Subset Data for single country
df_india = df_wdi[df_wdi["Country Name"] == "India"]

# %%
df_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 89 to 10722
# Data columns (total 11 columns):
#  #   Column                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                       --------------  -----
#  0   Year                                                                                                         50 non-null     int64
#  1   Country Name                                                                                                 50 non-null     object
#  2   Country Code                                                                                                 50 non-null     object
#  3   GDP per capita (constant 2010 US$)                                                                           50 non-null     float64
#  4   Population, total                                                                                            50 non-null     float64
#  5   CO2 emissions (metric tons per capita)                                                                       48 non-null     float64
#  6   Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)  1 non-null      float64
#  7   PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                 12 non-null     float64
#  8   Life expectancy at birth, total (years)                                                                      49 non-null     float64
#  9   Mortality rate, under-5 (per 1,000 live births)                                                              49 non-null     float64
#  10  Literacy rate, youth female (% of females ages 15-24)                                                        6 non-null      float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 4.7+ KB

# %%
plt.subplot(2, 1, 1)
sns.scatterplot(data=df_india, x="Year", y="GDP per capita (constant 2010 US$)")
plt.xlabel("Year")
plt.ylabel("GDP per capita \n (Constant 2010 US$)")
plt.title("India's GDP per Capita over Time")

plt.subplot(2, 1, 2)
sns.scatterplot(data=df_india, x="Year", y="CO2 emissions (metric tons per capita)")
plt.xlabel("Year")
plt.ylabel("CO2 emissions per capita \n (metric tons)")
plt.title("India's CO2 emissions per Capita over Time")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 7
#
# Now add a second series. Facet your plot so that the two subplots are positioned so that they are effectively sharing the same time axes (e.g., if you draw a line up from 2010 on one plot, you get to 2010 on the other).
#
# Rather than telling you exactly how to do it, however, I'll point you to the [seaborn tutorial](https://seaborn.pydata.org/tutorial/objects_interface#faceting-and-pairing-subplots). It has examples that don't do exactly what you want, but should be close enough you can guess-and-check to the solution you want!
#
# Use your detective skills (and some guess and check work) to figure out how to get it to work!

# %%
df_compare = df_wdi[df_wdi["Country Name"].isin(["India", "Pakistan"])]

(
    so.Plot(
        df_compare,
        x="Year",
        y="GDP per capita (constant 2010 US$)",
        color="Country Name",
    )
    .facet(col="Country Name", wrap=1)
    .add(so.Dots())
    .label(
        y="GDP per Capita",
        x="Year",
        title="India vs Pakistan GDP per Capita over Time",
    )
)
